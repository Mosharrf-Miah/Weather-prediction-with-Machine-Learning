# %% [markdown]
# # Data Scaling

# %% [markdown]
# ### This script contains the following:
# ####  1. Importing Libraries and Dataset
# ####  2. Scaling

# %% [markdown]
# ### 1. Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
path = r'C:\Users\mosh_\OneDrive\Desktop\Career Foundry\Machine Learning with Python\Achievement 1- Basic Machine Learning for Analysi\Data Sets'

# %%
path
# Out:
# 'C:\\Users\\mosh_\\OneDrive\\Desktop\\Career Foundry\\Machine Learning with Python\\Achievement 1- Basic Machine Learning for Analysi\\Data Sets'

# %%
df = pd.read_csv(os.path.join(path, 'weather-prediction-dataset-processed.csv'))

# %%
df
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0      19600101      1                  7               2.1            0.85
# 1      19600102      1                  6               2.1            0.84
# 2      19600103      1                  8               2.1            0.90
# 3      19600104      1                  3               2.1            0.92
# 4      19600105      1                  6               2.1            0.95
# ...         ...    ...                ...               ...             ...
# 22945  20221027     10                  1               2.1            0.79
# 22946  20221028     10                  6               2.1            0.77
# 22947  20221029     10                  4               2.1            0.76
# 22948  20221030     10                  5               2.1            0.80
# 22949  20221031     10                  5               2.1            0.84
#
# ...

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %%
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
df.shape
# Out:
# (22950, 171)

# %%
# removing nan 
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22950, 171)

# %% [markdown]
# ### 2. Scaling

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.
scaled_features = StandardScaler().fit_transform(df.values)

df_scaled = pd.DataFrame(scaled_features, index=df.index, columns=df.columns)

df_scaled ['DATE'] = df['DATE']

df_scaled ['MONTH'] = df['MONTH']

# %%
df_scaled
# Out:
#              id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# 0     -1.731975  19600101      1           0.660514          -0.02793
# 1     -1.731824  19600102      1           0.244897          -0.02793
# 2     -1.731673  19600103      1           1.076130          -0.02793
# 3     -1.731523  19600104      1          -1.001953          -0.02793
# 4     -1.731372  19600105      1           0.244897          -0.02793
# ...         ...       ...    ...                ...               ...
# 22945  1.731372  20221027     10          -1.833187          -0.02793
# 22946  1.731523  20221028     10           0.244897          -0.02793
# 22947  1.731673  20221029     10          -0.586336          -0.02793
# 22948  1.731824  20221030     10          -0.170720          -0.02793
# 22949  1.731975  20221031     10          -0.170720          -0.02793
#
#        BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# 0            0.826097       -0.001949               -1.101066
# ...

# %%
# Compare the original vs. scaled data

df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# Export dataframe as CSV
df_scaled.to_csv(os.path.join(path, 'Data_scaled.csv'))
